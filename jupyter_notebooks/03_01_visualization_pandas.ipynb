# %% [markdown]
# # Visualisierungsbeispiele in pandas
#
# Heiko Rölke

# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('dark_background')

# %%
#Daten wie im vorigen Beispiel

df1 = pd.DataFrame({"years" : [1950, 1960, 1970, 1980, 1990, 2000, 2010],
                    "gdp" : [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]})

#Standard-Diagrammtyp ist ein Linien-Diagramm
df1.plot()

#Mmh, nicht wie gewünscht - woran liegt das?
# Out:
# <AxesSubplot: >

# %%
#wie sehen denn die Daten aus?
df1
# Out:
#    years      gdp
# 0   1950    300.2
# 1   1960    543.3
# 2   1970   1075.9
# 3   1980   2862.5
# 4   1990   5979.6
# 5   2000  10289.7
# 6   2010  14958.3

# %%
#gewünscht wäre "years" als Index
df1.set_index("years", inplace=True)
df1
# Out:
#            gdp
# years
# 1950     300.2
# 1960     543.3
# 1970    1075.9
# 1980    2862.5
# 1990    5979.6
# 2000   10289.7
# 2010   14958.3

# %%
df1.plot()

#Ah, besser!
# Out:
# <AxesSubplot: xlabel='years'>

# %%
#machen wir die Daten etwas interessanter...
made_up_values = [1500, 2500, 1000, 1500, 1250, 2000, 4000]
df1["gdp2"] = made_up_values
df1
# Out:
#            gdp  gdp2
# years
# 1950     300.2  1500
# 1960     543.3  2500
# 1970    1075.9  1000
# 1980    2862.5  1500
# 1990    5979.6  1250
# 2000   10289.7  2000
# 2010   14958.3  4000

# %%
df1.plot()
# Out:
# <AxesSubplot: xlabel='years'>

# %%
#weitere Diagrammformen
df1.plot.bar()
# Out:
# <AxesSubplot: xlabel='years'>

# %%
df1.plot.bar(stacked=True)
# Out:
# <AxesSubplot: xlabel='years'>

# %%
df1.plot.barh()
# Out:
# <AxesSubplot: ylabel='years'>

# %%
df1.plot.area()
# Out:
# <AxesSubplot: xlabel='years'>

# %%
df1.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot: ylabel='gdp'>, <AxesSubplot: ylabel='gdp2'>],
#       dtype=object)

# %%
df1["gdp"].plot.pie()
# Out:
# <AxesSubplot: ylabel='gdp'>

# %%
df1.plot.scatter(x="gdp", y="gdp2")

#nicht so sinnvoll, wir brauchen andere Daten
# Out:
# <AxesSubplot: xlabel='gdp', ylabel='gdp2'>

# %%
#bauen wir uns schnell welche: Grösse und Gewicht
import random
mu = 170 #mean
sigma = 6 #stddev
sample = 100
random.seed(0)
height = [random.gauss(mu, sigma) for _ in range(sample)]  # Normalverteilung um 170cm
weight = [(h-100) * (0.75 + random.random()/2) for h in height]
weight2 = [(h-100) * (1.5 + random.random()/2) for h in height]
# Gewicht streut gleichverteilt zwischen 3/4 und 5/4 der Grösse - 100

gca = plt.gca()

df2 = pd.DataFrame({"height":height, "weight":weight})
df2.plot.scatter(x="height", y="weight", ax=gca)

df3 = pd.DataFrame({"height":height, "weight":weight2})
df3.plot.line(x="height", y="weight", ax=gca)
# Out:
# <AxesSubplot: xlabel='height', ylabel='weight'>

# %% [markdown]
# # Anpassung der Plots wie in matplotlib gewohnt
# (ohne weitere Beispiele)
